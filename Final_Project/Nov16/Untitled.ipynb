# %%
# from youtube video:
# https://www.youtube.com/watch?v=ollW8lwZxNE

# %%
# Import the necessary python packages
import networkx as nx
import matplotlib.pyplot as plt

# %%
D = nx.Graph()

# %%
D.add_node("a")
D.add_node("b")
D.add_node("c")
D.add_node("d")
D.add_node("e")
D.add_node("f")
D.add_node("g")
D.add_node("h")
D.add_node("i")
D.add_node("j")
D.add_node("k")
D.add_node("l")
D.add_node("m")
D.add_node("n")
D.add_node("o")
D.add_node("p")

# %%
D.add_edge("a","b")
D.add_edge("a","p")
D.add_edge("p","o")
D.add_edge("o","b")
D.add_edge("o","n")
D.add_edge("n","l")
D.add_edge("l","m")
D.add_edge("l","d")
D.add_edge("d","b")
D.add_edge("a","c")
D.add_edge("d","c")
D.add_edge("l","k")
D.add_edge("k","j")
D.add_edge("j","i")
D.add_edge("h","i")
D.add_edge("h","f")
D.add_edge("f","d")
D.add_edge("c","e")
D.add_edge("e","g")
D.add_edge("g","j")

# %%
# Set figure size
# plt.figure(figuresize=(10,0))

# Set your pos (layout is an option)

# Set your node options
node_options = {"node_color": "black", "node_size": 30}

# Set your edge options
edge_options = {"width": .50, "alpha": .5, "edge_color": "black"}

# %%
nx.draw(D, node_)
